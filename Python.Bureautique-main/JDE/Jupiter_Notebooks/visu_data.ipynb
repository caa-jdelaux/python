# %%
# Visualiser une courbe sin(x) avec matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Données
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

print(x)
print(y)
# Out:
# [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
#  4.95038842 5.01385494 5.07732146 5.14078798 5.2042545  5.26772102
# ...

# %%
# Tracer la courbe
plt.plot(x, y, label='sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Courbe sin(x)')

plt.legend()
plt.show()

# %%
# Créer plusieurs courbes
y2 = np.cos(x)
plt.plot(x, y, label='sin(x)')
plt.plot(x, y2, label='cos(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Courbe sin(x) et cos(x)')
plt.legend()
plt.show()

# %%
# Créer un histogramme
data = np.random.randn(1000)
plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogramme')
plt.show()

# %%
# Créer un nuage de points
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Nuage de points')
plt.show()

# %%
# Créer un nuage de points avec des couleurs
x = np.random.randn(1000)
y = np.random.randn(1000)
colors = np.random.rand(1000)
plt.scatter(x, y, c=colors, cmap='viridis')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Nuage de points')
plt.colorbar()
plt.show()

# %%
# utilisation de seaborn pour des graphiques plus jolis
import seaborn as sns
sns.set()
plt.plot(x, y)
plt.show()

# %%
# Afficher un histogramme avec seaborn et pandas
import pandas as pd
data = np.random.randn(1000)
df = pd.DataFrame(data, columns=['x'])
sns.histplot(df, bins=30, kde=True)
plt.show()

# %%
# Afficher l'avancement des tests OK / KO / non testé dans le temps
import matplotlib.pyplot as plt
import pandas as pd

data = {'Timestamp': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04'],
    'OK': [1, 5, 9, 10],
    'KO': [0, 1, 1, 0],
    'Not Tested': [9, 4, 0, 0]}

df = pd.DataFrame(data)
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['Timestamp'] = df['Timestamp'].dt.strftime('%d/%m/%y')

# Afficher les données
print(df)



# Créer un histogramme
ax = df.set_index('Timestamp').plot(kind='bar', stacked=True, color=['green', 'red', 'blue'], width=1, edgecolor='none')

# Vérifier si la valeur est différente de 0 et afficher la légende correspondante
for col in df.columns[1:]:
    for i, val in enumerate(df[col]):
        if val != 0:
            ax.text(i, val/2, str(val), va='bottom', ha='center')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('date')
plt.show()
# Out:
#   Timestamp  OK  KO  Not Tested
# 0  01/01/24   1   0           9
# 1  02/01/24   5   1           4
# 2  03/01/24   9   1           0
# 3  04/01/24  10   0           0

# %%
# Visualiser des coordonnées géographiques sur une carte en utilisant folium
import folium

# Définir les coordonnées du centre de la carte
latitude = 48.8566
longitude = 2.3522
coordinates = [ {'name': 'Paris', 'latitude': 48.8566, 'longitude': 2.3522},
                {'name': 'New York', 'latitude': 40.7128, 'longitude': -74.0060},
                {'name': 'Tokyo', 'latitude': 35.6895, 'longitude': 139.6917}]


# Create a map object
m = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers for each coordinate
for coord in coordinates:
    folium.Marker(location=[coord['latitude'], coord['longitude']], popup=coord['name']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Graphique intéractif avec panel
import panel as pn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Créer des données aléatoires
np.random.seed(0)
x = np.linspace(0, 10, 100)
y = np.random.randn(100)*np.sin(x)

# Créer un DataFrame à partir des données
df = pd.DataFrame({'x': x, 'y': y})

# Créer une figure matplotlib
fig, ax = plt.subplots()
ax.plot(df['x'], df['y'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Graphique interactif')

# Créer un panneau Panel pour afficher la figure
panel = pn.pane.Matplotlib(fig)

# Afficher le panneau
panel.show()
# Out:
# Launching server at http://localhost:59965
